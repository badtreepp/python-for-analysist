# %% [markdown]
# <!-- Подключение гугл диска для гугл колаба
# # Подключение GoogleДиска
# from google.colab import drive
# drive.mount('/content/gdrive', force_remount=Tr -->ue)

# %% [markdown]
# ##### Задание 1
# - Скачать данные по ссылке https://drive.google.com/file/d/1MpAdHAl727fO3oW32NO4FpSRhUBUfjfS
# - Считать данные с помощью pandas
# -
# Вывести на экран первые 5 стокр
#
# - Постройте график
# - Назовите график
# - Сделайте именование оси x и оси y
# - Сделайте выводык
# 1.1 Изучите распределение количества памяти (Memory_Amount) с помощью matplotlте выводы

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('laptops_10.csv')
df.head()
# Out:
#   Company      Product   TypeName  Inches                         Cpu   Ram  \
# 0   Apple  MacBook Pro  Ultrabook    13.3        Intel Core i5 2.3GHz   8GB
# 1   Apple  Macbook Air  Ultrabook    13.3        Intel Core i5 1.8GHz   8GB
# 2      HP       250 G6   Notebook    15.6  Intel Core i5 7200U 2.5GHz   8GB
# 3   Apple  MacBook Pro  Ultrabook    15.4        Intel Core i7 2.7GHz  16GB
# 4   Apple  MacBook Pro  Ultrabook    13.3        Intel Core i5 3.1GHz   8GB
#
#                             Gpu  OpSys  Weight  Price_euros Cpu_Company  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37      1339.69       Intel
# 1        Intel HD Graphics 6000  macOS    1.34       898.94       Intel
# 2         Intel HD Graphics 620  No OS    1.86       575.00       Intel
# 3            AMD Radeon Pro 455  macOS    1.83      2537.45       Intel
# 4  Intel Iris Plus Graphics 650  macOS    1.37      1803.60       Intel
#
#    Memory_Amount   Memory_Type
# 0            128           SSD
# 1            128  FlashStorage
# 2            256           SSD
# 3            512           SSD
# 4            256           SSD

# %%
plt.figure(figsize=(16, 8))
plt.hist(df['Memory_Amount'], bins=32)
plt.title('Распределение памяти')
plt.xlabel('GB')
plt.ylabel('Количество')
plt.xticks(range(0, 2100, 64), rotation=30)
plt.yticks(range(0, 550, 20))
plt.grid()
;
# Out:
# ''

# %% [markdown]
# 1.2 Изучите распределение стоимости ноутбуков (Price_euros) с помощью matplotlib

# %%
plt.figure(figsize=(16, 8))
plt.hist(df['Price_euros'], bins=59)
plt.title('Распределение стоимости')
plt.xlabel('EUR')
plt.ylabel('Количество')
plt.xticks(range(0, 6200, 100), rotation=40)
plt.yticks(range(0, 105, 5))
plt.grid()
;
# Out:
# ''

# %% [markdown]
# 1.3 Изучите распределение веса ноутбуков (Weight) с помощью matplotlib

# %%
plt.figure(figsize=(16, 6))
plt.hist(df['Weight'], bins=40)
plt.title('Распределение веса ноутбуков')
plt.xlabel('Вес, кг')
plt.ylabel('Количество')
plt.xticks(np.arange(0.7, 4.8, 0.1), range(700, 4800, 100), rotation=40)
plt.yticks(range(0, 160, 10))
plt.grid()
;
# Out:
# ''

# %% [markdown]
# ## Задание 2.
#
# Постройте график
# Сделайте выводы
# 2.1 Изучите распределение типов носителя (Memory_Type)

# %%
mem_type = df['Memory_Type'].value_counts()
mem_type
# Out:
# Memory_Type
# SSD             641
# HDD             576
# FlashStorage     74
# Hybrid           12
# Name: count, dtype: int64

# %%
plt.pie(mem_type.values, labels=mem_type.index, autopct='%.1f%%')

;
# Out:
# ''

# %% [markdown]
# 2.2 Изучите распределение компаний производителей (Company)

# %%
company = df['Company'].value_counts()
company
# Out:
# Company
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: count, dtype: int64

# %%
plt.figure(figsize=(16, 6))
plt.bar(company.index, company)
plt.title('Распределение производителей ноутбуков')
plt.xlabel('Производитель')
plt.ylabel('Количество')
plt.xticks(rotation=35)
plt.yticks(range(0, 310, 25))
plt.grid()         
;
# Out:
# ''

# %% [markdown]
# 2.3 Изучите распределение операционной системы (OpSys)

# %%
opsys_count = df['OpSys'].value_counts()
opsys_count
# Out:
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         27
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
plt.figure(figsize=(16, 6))
plt.bar(opsys_count.index, opsys_count)
plt.title('Распределение операционных систем')
plt.xlabel('ОС')
plt.ylabel('Количество')
plt.xticks(rotation=35)
plt.yticks(range(0, 1100, 100))
plt.grid()         
;
# Out:
# ''

# %% [markdown]
# 2.4 Изучите распределение компаний производителей CPU (Cpu_Company)

# %%
cpu_company_count = df['Cpu_Company'].value_counts()
cpu_company_count
# Out:
# Cpu_Company
# Intel      1240
# AMD          62
# Samsung       1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(16, 6))
plt.pie(cpu_company_count, labels=cpu_company_count.index, autopct='%.1f%%')
plt.title('Распределение компаний производителей ОС')   
;
# Out:
# ''

# %% [markdown]
# ## Задание 3.
#
# Изучите взаимосвязь компаний производителей ноутбуков и компаний производителей процессоров, используя сложенную или многорядовую столбчатую диаграмму
# Процессоры от Samsung не изучайте

# %%
df.sample()
# Out:
#      Company          Product TypeName  Inches                          Cpu  \
# 1047     MSI  GT72S Dominator   Gaming    17.3  Intel Core i7 6820HK 2.7GHz
#
#        Ram                      Gpu       OpSys  Weight  Price_euros  \
# 1047  16GB  Nvidia GeForce GTX 980M  Windows 10    3.78      1545.64
#
#      Cpu_Company  Memory_Amount Memory_Type
# 1047       Intel            256         HDD

# %%
data = pd.crosstab(index=df['Company'], columns=df['Cpu_Company']).reset_index()
data.drop(columns='Samsung', inplace=True)
data
# Out:
# Cpu_Company    Company  AMD  Intel
# 0                 Acer   10     93
# 1                Apple    0     21
# 2                 Asus   11    147
# 3                Chuwi    0      3
# 4                 Dell    0    297
# 5              Fujitsu    0      3
# 6               Google    0      3
# 7                   HP   25    249
# 8               Huawei    0      2
# 9                   LG    0      3
# 10              Lenovo   16    281
# 11                 MSI    0     54
# 12            Mediacom    0      7
# 13           Microsoft    0      6
# 14               Razer    0      7
# 15             Samsung    0      8
# 16             Toshiba    0     48
# 17                Vero    0      4
# 18              Xiaomi    0      4

# %% [markdown]
# 3.1 Постройте график в абсолютных величинах

# %%
plt.figure(figsize=(16, 8))
nticks = data.index
offset = 0.2
w = 0.4

plt.bar(nticks - offset, data['Intel'], width=w)
plt.bar(nticks + offset, data['AMD'], width=w)
plt.xticks(nticks, data['Company'], rotation=30)
plt.title('Ноутбуки')
plt.xlabel('Производитель')
plt.ylabel('Количество')
plt.legend(['Intel', 'AMD'])
;
# Out:
# ''

# %% [markdown]
# 3.2 Постройте график в относительных величинах

# %%
data = pd.crosstab(index=df['Company'], columns=df[df['Cpu_Company'] != 'Samsung']['Cpu_Company'], normalize='index').reset_index()
data
# Out:
# Cpu_Company    Company       AMD     Intel
# 0                 Acer  0.097087  0.902913
# 1                Apple  0.000000  1.000000
# 2                 Asus  0.069620  0.930380
# 3                Chuwi  0.000000  1.000000
# 4                 Dell  0.000000  1.000000
# 5              Fujitsu  0.000000  1.000000
# 6               Google  0.000000  1.000000
# 7                   HP  0.091241  0.908759
# 8               Huawei  0.000000  1.000000
# 9                   LG  0.000000  1.000000
# 10              Lenovo  0.053872  0.946128
# 11                 MSI  0.000000  1.000000
# 12            Mediacom  0.000000  1.000000
# 13           Microsoft  0.000000  1.000000
# 14               Razer  0.000000  1.000000
# 15             Samsung  0.000000  1.000000
# 16             Toshiba  0.000000  1.000000
# 17                Vero  0.000000  1.000000
# 18              Xiaomi  0.000000  1.000000

# %%
plt.figure(figsize=(16, 8))

plt.bar(data['Company'], data['Intel'])
plt.bar(data['Company'], data['AMD'], bottom=data['Intel'])
plt.xticks(nticks, data['Company'], rotation=30)
plt.title('Ноутбуки')
plt.xlabel('Производитель')
plt.ylabel('Доля ноутбуков')
plt.legend(['Intel', 'AMD'])
;
# Out:
# ''

# %% [markdown]
# ## Задание 4.
# - Постройте график
# - Назовите график
# - Сделайте именование оси x и оси y
# - Сделайте выводы

# %% [markdown]
# 4.1 Изучите взаимосвязь стоимости ноутбука и компании производителя процессора

# %%
df.sample()
# Out:
#     Company         Product  TypeName  Inches  \
# 409  Lenovo  Lenovo IdeaPad  Notebook    11.6
#
#                                       Cpu  Ram                    Gpu  \
# 409  Intel Celeron Dual Core N3350 1.1GHz  2GB  Intel HD Graphics 500
#
#           OpSys  Weight  Price_euros Cpu_Company  Memory_Amount   Memory_Type
# 409  Windows 10    1.15       304.45       Intel             32  FlashStorage

# %%
sns.boxplot(x=df['Price_euros'], y=df['Cpu_Company'])
plt.title('Взаимосвязь стоимости и компании производителя')

;
# Out:
# ''

# %% [markdown]
# 4.2 Изучите взаимосвязь стоимости ноутбука и типа носителя памяти

# %%
sns.boxplot(x=df['Price_euros'], y=df['Memory_Type'])
plt.title('Взаимосвязь стоимости и типа носителя памяти')

;
# Out:
# ''

# %% [markdown]
# 4.3 Изучите взаимосвязь стоимости ноутбука и кол-ва оперативной памяти

# %%
sns.boxplot(x=df['Price_euros'], y=df['Ram'])
plt.title('Взаимосвязь стоимости и кол-ва оперативной памяти')

;
# Out:
# ''

# %% [markdown]
# 4.4 Изучите взаимосвязь стоимости ноутбука и компании производителя

# %%
sns.boxplot(x=df['Price_euros'], y=df['Company'])
plt.title('Взаимосвязь стоимости и компании производителя')

;
# Out:
# ''

# %% [markdown]
# ## Задание 5*.
#
# Постройте матрицу корреляций для таблицы

# %%
df.sample()
# Out:
#     Company                               Product  TypeName  Inches  \
# 555    Asus  A541NA-GO342 (N3350/4GB/500GB/Linux)  Notebook    15.6
#
#                                       Cpu  Ram                    Gpu  OpSys  \
# 555  Intel Celeron Dual Core N3350 1.1GHz  4GB  Intel HD Graphics 500  Linux
#
#      Weight  Price_euros Cpu_Company  Memory_Amount Memory_Type
# 555     2.0        224.0       Intel            500         HDD

# %%
corr_matrix = df[['Inches', 'Weight', 'Price_euros', 'Memory_Amount']].corr().round(2)
corr_matrix
# Out:
#                Inches  Weight  Price_euros  Memory_Amount
# Inches           1.00    0.83         0.07           0.27
# Weight           0.83    1.00         0.21           0.18
# Price_euros      0.07    0.21         1.00          -0.13
# Memory_Amount    0.27    0.18        -0.13           1.00

# %%
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidth=1)
# Out:
# <Axes: >
